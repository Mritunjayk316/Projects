# %%
import pandas as pd
from datetime import date
df=pd.read_csv("D:\\web devl notes\\3r class\\car data.csv")
df.head(5)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.Fuel_Type.value_counts()
# Out:
# Petrol    139
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64

# %%
df.Transmission.value_counts()
# Out:
# Manual       170
# Automatic     31
# Name: Transmission, dtype: int64

# %%
df["New_Selling_price"]=df["Selling_Price"]*10000
df.head(5)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  New_Selling_price
# 0      Dealer       Manual      0            33500.0
# 1      Dealer       Manual      0            47500.0
# 2      Dealer       Manual      0            72500.0
# 3      Dealer       Manual      0            28500.0
# 4      Dealer       Manual      0            46000.0

# %%
df["New_present_price"]=df["Present_Price"]*10000
df.head(5)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  New_Selling_price  New_present_price
# 0      Dealer       Manual      0            33500.0            55900.0
# 1      Dealer       Manual      0            47500.0            95400.0
# 2      Dealer       Manual      0            72500.0            98500.0
# 3      Dealer       Manual      0            28500.0            41500.0
# 4      Dealer       Manual      0            46000.0            68700.0

# %%
from datetime import date
today_date=date.today()
print(today_date)
df["car_age"]=today_date.year-df["Year"]
df.head(5)
# Out:
# 2023-04-16
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  New_Selling_price  New_present_price  \
# 0      Dealer       Manual      0            33500.0            55900.0
# 1      Dealer       Manual      0            47500.0            95400.0
# 2      Dealer       Manual      0            72500.0            98500.0
# 3      Dealer       Manual      0            28500.0            41500.0
# 4      Dealer       Manual      0            46000.0            68700.0
#
#    car_age
# 0        9
# 1       10
# 2        6
# 3       12
# 4        9

# %%
df.drop(["Car_Name"],axis=1,inplace=True)
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  New_Selling_price  New_present_price  car_age
# 0       Manual      0            33500.0            55900.0        9
# 1       Manual      0            47500.0            95400.0       10
# 2       Manual      0            72500.0            98500.0        6
# 3       Manual      0            28500.0            41500.0       12
# 4       Manual      0            46000.0            68700.0        9

# %%
corr=df.corr()
corr
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_404\3182140910.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
#                        Year  Selling_Price  Present_Price  Kms_Driven  \
# Year               1.000000       0.346141      -0.060279   -0.705477
# Selling_Price      0.346141       1.000000       0.826635   -0.101332
# Present_Price     -0.060279       0.826635       1.000000    0.253505
# Kms_Driven        -0.705477      -0.101332       0.253505    1.000000
# Owner             -0.152243      -0.083620       0.047002    0.197756
# New_Selling_price  0.346141       1.000000       0.826635   -0.101332
# New_present_price -0.060279       0.826635       1.000000    0.253505
# car_age           -1.000000      -0.346141       0.060279    0.705477
#
# ...

# %%
import seaborn as sns
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
df.drop(["Seller_Type"],axis=1,inplace=True)

# %%
pd.get_dummies(df,drop_first=True)
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Owner  New_Selling_price  \
# 0    2014           3.35           5.59       27000      0            33500.0
# 1    2013           4.75           9.54       43000      0            47500.0
# 2    2017           7.25           9.85        6900      0            72500.0
# 3    2011           2.85           4.15        5200      0            28500.0
# 4    2014           4.60           6.87       42450      0            46000.0
# ..    ...            ...            ...         ...    ...                ...
# 196  2016           9.50          11.60       33988      0            95000.0
# 197  2015           4.00           5.90       60000      0            40000.0
# 198  2009           3.35          11.00       87934      0            33500.0
# 199  2017          11.50          12.50        9000      0           115000.0
# 200  2016           5.30           5.90        5464      0            53000.0
#
# ...

# %%
df.isna().sum()
# Out:
# Year                 0
# Selling_Price        0
# Present_Price        0
# Kms_Driven           0
# Fuel_Type            0
# Transmission         0
# Owner                0
# New_Selling_price    0
# New_present_price    0
# car_age              0
# dtype: int64

# %%
df.to_csv("clean_data_1.csv",index=False)
